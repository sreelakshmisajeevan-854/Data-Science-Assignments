# %% [markdown]
# <a href="https://colab.research.google.com/github/sreelakshmisajeevan-854/Data-science/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 1: Prime Numbers

# %%
num=int(input("Enter the number : "))
if num<=1:
  print(num,' is not a prime number.')
elif num==2:
  print(num,' is a prime number.')
else:
  count=0
  for i in range(2,num):
    if num%i==0:
      count+=1
  if count==0:
    print(num,' is a prime number.')
  else:
    print(num,' is not a prime number.')
# Out:
# Enter the number : 2
# 2  is a prime number.

# %% [markdown]
# Exercise 2: Product of Random Numbers

# %%
import random
num1=random.randint(1,1000)
num2=random.randint(1,1000)
prod=num1*num2
guess=int(input("Predict the product of the two random number:"))
if prod==guess:
    print('Yup!,Correct prediction')
else:
    print('Oops!,Incorrect prediction')
    print('The correct answer is:',prod)
# Out:
# Predict the product of the two random number:1234
# Oops!,Incorrect prediction
# The correct answer is: 467584

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers

# %%
#Squares of even number
for i in range(100,200):
    if i%2==0: #Check if the number is even
        print(i*i)
# Out:
# 10000
# 10404
# 10816
# 11236
# 11664
# 12100
# 12544
# 12996
# 13456
# 13924
# 14400
# 14884
# 15376
# 15876
# 16384
# 16900
# 17424
# 17956
# 18496
# 19044
# 19600
# 20164
# 20736
# 21316
# 21904
# 22500
# 23104
# 23716
# 24336
# 24964
# 25600
# 26244
# 26896
# 27556
# 28224
# 28900
# 29584
# 30276
# 30976
# 31684
# 32400
# 33124
# 33856
# 34596
# 35344
# 36100
# 36864
# 37636
# 38416
# 39204

# %% [markdown]
# Exercise 4:

# %%
total=(2000*4)+1500+(3*300)+2400
if total>10000:
    final=total-(total*(10/100))
else:
    final=total
print('The final bill:',final)
# Out:
# The final bill: 11520.0
